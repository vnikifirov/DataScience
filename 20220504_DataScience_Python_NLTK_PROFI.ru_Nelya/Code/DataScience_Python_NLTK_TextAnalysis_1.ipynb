# %%
# Task description:
#У меня есть 985 комментариев о работе компании и пожеланиях клиентов. 
#1. Нужно получить коэффициенты сентиментов по каждому, то есть насколько комментарий 
#положительный или отрицательный. 
#2. Также желательно определить, к каким отделам относятся 
#эти комментарии, чтобы понять, кому их надо брать в работу. 
#3. Задача максимум: ещё и связать 
# коэффициенты сентиментов с количественными оценками, которые клиенты выставляли по 
# отдельным критериям работы компании. Вы такое умеете делать?

# %%
import pandas as pd #импорт модуля пандас под именем пд, необходимого для работы с таблицей из экселя
from string import punctuation #импорт объекта для удаления знаков препинания между словами
import os, os.path, subprocess
import math

# English language
import nltk #импорт пакета nltk для NLP
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import stopwords #импорт объекта для удаления лишних (стоп) слов из модуля corpus из пакета nltk для NLP

nltk.download([
    "punkt",
    "stopwords",
    "averaged_perceptron_tagger"
])

#Russian language analyzer
from dostoevsky.tokenization import RegexTokenizer
from dostoevsky.models import FastTextSocialNetworkModel

from IPython.display import Image
from PIL import Image

# Import required libraries
from nltk import pos_tag, word_tokenize, RegexpParser

# Visualization 
import numpy as np # Import numpy lib
from numpy import convolve # 
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /Users/lucifer/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/lucifer/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/lucifer/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def setup(path: str):# = os.path.abspath(input("Enter path of your Excel document: "))):
    try:
         return pd.read_excel(path,usecols='A,J') #выбираем только колонки A, J для идентификации и анализа
    except OSError:
        if not os.path.isfile(path):
            print("Excel document isn't exist")

def GetDataFromDocByKey(document: list, key: str) -> list:
    if len(document) == 0:
        raise ValueError('Argument empty', type(document))
        
    if len(key) == 0:
        raise ValueError('Argument empty', type(key))  
    
    return document[key].astype(str).tolist()            

# TODO: It isn't best code it should be ovewrited to follow SOLID principles  
def matchrus(text: str, alphabet = set('абвгдеёжзийклмнопрстуфхцчшщъыьэюя')) -> bool:
    return not alphabet.isdisjoint(text.lower()) #функция для проверки, если комментарий написан на русском

# TODO: It isn't best code it should be ovewrited to follow SOLID principles 
def matcheng(text: str, alphabet = set('abcdefghijklmnopqrstuvwxyz')) -> bool:
    return not alphabet.isdisjoint(text.lower()) #функция для проверки, если комментарий написан на английском
    # x - 'a' >= 0 && x - 'a' <= 26
    
def GetCommentsRusOrEng(clientsIds: list, comments: list) -> list:
    if len(clientsIds) == 0:
        raise ValueError('Argument empty', type(clientsIds))
        
    if len(comments) == 0:
        raise ValueError('Argument empty', type(comments))
    
    russiancomments = [] # создаем три пустых массива, чтобы в них записать, соответственно, комментарии на русском
    englishcomments = [] # на английском
    nulcomments = [] # и "нулевые"
    
    for i in range(0, len(clientsIds)): #цикл, который исполняется для каждого id клиента
        #array = [] #пустой массив
        #array.append(i) #в него записываем порядковый номер строки, начиная с 0
        #array.append(clientsIds[i]) #следом в него записываем id клиента
        #array.append(comments[i]) #и его комментарий
        
        comment = comments[i]

        # TODO: I think it's possible to move the check to a separate method
        if matchrus(comment):
            russiancomments.append(comment) #если комментарий на русском, записываем в массив для руссских комментариев
        elif matcheng(comment):
            englishcomments.append(comment) #аналогично для английского
        else:
            nulcomments.append(comment) #оставшиеся попадают в "нулевой" массив
            
    return russiancomments, englishcomments, nulcomments

def PrintComments(comments: list, lang: str) -> None:
    if len(comments) == 0:
        raise ValueError('Argument empty', type(comments))
        
    if len(lang) == 0:
        raise ValueError('Argument empty', type(lang))
    
    print(f"{lang} comments", comments)
    
def GetStopwords(lang: str) -> list:
    if len(lang) == 0:
        raise ValueError('Argument empty', type(lang))
    
    return stopwords.words(lang)

def GetTokensOrWords(comments: list, stopwords = None, punctuation = None) -> []:
    if len(comments) == 0:
        raise ValueError('Argument empty', type(comments))
    
    if stopwords is not None and len(stopwords) == 0:
        raise ValueError('Argument empty', type(stopwords))
        
    if punctuation is not None and len(punctuation) == 0:
        raise ValueError('Argument empty', type(punctuation))
    
    tokens = []
    
    for i in range(0, len(comments)): #делим тексты на токены, то есть на отдельные слова, выкидывая знаки препинания и стоп-слова
        #text = comments[i][2] # jagged array
        text = comments[i]
        tokens = nltk.word_tokenize(text.lower())
        if stopwords is not None and punctuation is not None:
            tokens = [token for token in tokens if token not in stopwords and token not in punctuation]
    return tokens

def comment_is_positive(sia, comment: str, percents: bool = False) -> bool:
    if sia == None:
        raise ValueError('Argument empty', type(sia))
    
    if len(comment) == 0:
        raise ValueError('Argument empty', type(comment))
        
    """True if comment has positive compound sentiment, False otherwise."""
    return sia.polarity_scores(comment)["compound"] > 0 

# English coments sentiemnt analysis
# Compund or aggregate (true is Positive or false is Negative) 
def comment_is_positive_percents(sia, comment: str) -> float:
    if sia == None:
        raise ValueError('Argument empty', type(sia))
    
    if len(comment) == 0:
        raise ValueError('Argument empty', type(comment))
        
    """True if comment has positive compound sentiment, False otherwise."""
    return sia.polarity_scores(comment)["pos"], sia.polarity_scores(comment)["neg"]

def PrintSentiments(sia, comments: []) -> None:
    if sia is None:
        raise ValueError('Argument empty', type(sia))
    
    if len(comments) == 0:
        raise ValueError('Argument empty', type(comments))
    
    for comment in comments:
        print(">", "Positive:" if comment_is_positive(sia, comment) else "Negative:", comment)

def SentimentAnalyses(comments: [], lang: str = "Eng") -> None:
    if len(comments) == 0:
        raise ValueError('Argument empty', type(comments))
    
    if len(lang) == 0:
        raise ValueError('Argument empty', type(lang))
    
    print(f"Sentiment Analysis of {lang}")
    #if lang is "Russian" or lang is "Rus":
    if lang == "English" or lang == "Eng":
        sia = SentimentIntensityAnalyzer()
        PrintSentiments(sia, comments)
        
# Russian coments sentiemnt analysis
def GetSentimentsFrom(comments):
    tokenizer = RegexTokenizer()
    FastTextSocialNetworkModel.MODEL_PATH = '/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/fasttext-social-network-model.bin'
    sia = FastTextSocialNetworkModel(tokenizer=tokenizer)
    return sia.predict(comments)

# Create X and Y axis pints on coordinate system  
def GetSentiementByKey(sentiments, key):
    return list(map(lambda sentiment: sentiment[key], sentiments))

# %%
survey = setup("/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/Excel2.xlsx")
comments = GetDataFromDocByKey(survey, "Комментарий клиента") #создаем массив только с комментариями
clientsIds = GetDataFromDocByKey(survey, "Id шаблона") #создаем массив только с id клиента 
russiancomments, englishcomments, nulcomments = GetCommentsRusOrEng(clientsIds, comments)
russian_stopwords = GetStopwords("russian")
english_stopwords = GetStopwords("english")
russianWords = GetTokensOrWords(russiancomments, russian_stopwords, punctuation)
englishWords = GetTokensOrWords(englishcomments, english_stopwords, punctuation)
nulWords = GetTokensOrWords(nulcomments)

# %%
#получился массив в массиве на самом деле, но для простоты понимания ниже буду называть массивы в массиве строчками
PrintComments(russiancomments, "Russia")
PrintComments(englishcomments, "English")
PrintComments(nulcomments, "Nul")
print("\n\r")

print("Amount of Russia comments: ", len(russiancomments)) #печатаем количество строк в каждом массиве
print("Amount of English comments: ", len(englishcomments)) #так их можно сложить и ерепроверить, что сумма сошлась верно
print("Amount of Nul comments: ", len(nulcomments)) #можно это и булевой функцией записать коротко, но пока нужна наглядность для корректировки
print("\n\r")

print(russian_stopwords) #печатаем русские лишние (стоп) слова из пакета nltk, чтобы понимать, что будем дальше выкидывать
print(english_stopwords) #для английского отдельно

print ("Russian words", russianWords)
print ("English words", englishWords)
print ("Nul words", nulWords)
print("\n\r")

SentimentAnalyses(englishcomments)
# Out:
# Russia comments ['В целом всё хорошо, но иногда допускаются ошибки в оформлении документов.', 'все Вы делаете хорошо', 'ранее указывали, хотелось бы в ускоренном варианте получать счета фактуры, для возможности оприходования материала и корректной подачи ЗОВ день в день.', 'Поздно поступают документы по отгрузке .', 'встречаются ошибки по количеству. но редко', 'После перехода на ЭДО', 'С документами все четко.', 'Медленно подписываются дополнения на подтвержденный объем', 'Нет электронного документа УПД по отгрузке ДОТФ 24.10.2020.', 'Документы по ЭДО отправляются позже, чем машина приходит  на разгрузку', 'В 2020г. имелись проблемы с предоставлением оригиналов отгрузочных документов и ДС', 'Сроки выставления корректирующих документов в случае выявления расхождений оставляют желать лучшего', 'есть проблемы и "неудобство" в связи с использованием каждой стороной своего ПО для внутреннего согласования документов.', 'нет синхронизации работы по авансовым с/ф. Переодический перекос в налоговой', 'бывает что при размещении заказа в системе нет позиций номенклатуры', 'ЭДО это хорошо', 'иногда возникают неточности, связанные с нашими требованиями. А также иногда  документы предоставляются с задержкой.', 'Электронный документооборот требует доработки', 'Очень удобно получать все документы по ЭДО.', 'документы предоставляются точно в срок', 'Компания СИБУР одна из первых ВИНК внедривших электронный документооборот, что облегчает работу как покупателям так и продавцам', 'По сравнению с другими продавцами на бирже в секции "Нефтепродукты" Сибур быстрее всего направляет документы. Это, однозначно, большой плюс.', 'оперативность и профессионализм', 'Понравилась продуктивная работа с Маниной Екатериной и Хамитовым Денисом. Решение вопросов оперативно и с индивидуальным подходом.', 'Своевременная отправка электронных копий и оригиналов документов.', 'все нравиться', ' Оперативность принятия решений экспертом обособленного структурного подразделения в г. Новосибирске ООО "СИБУР"', 'оперативность принятия решений', 'Снижение цены на полипропилен в январе 2020 года', 'Самое главное - соблюдение объемов поставки продукции', 'компромиссные решения в период пандемии. обеспеченность сырьем на время профилактики завода', 'все хорошо', 'доставка, общение с менеджером', 'Косолапов Алексей отличный менеджер', 'прекрасный менеджер, замечательная работа логистики и сервиса отправки докуменетов', 'Очень приятно, что политика компании нацелена в том числе и на работу с малым бизнесом напрямую, без посредников!!!', 'Ненавязчивость и профессионализм менеджеров продаж', 'Клиентоориентированность', 'Клиентоориентированность', 'быстрый ответ на возникающие вопросы', 'Менеджер оперативно решает любые вопросы', 'клиентские мероприятия "круглый стол"', 'очень полезен тех сервис специалистов с проведением совместных испытаний и обсуждения рекомендаций', 'обещания всегда выполняются', 'Мне запомнилось изменение цены на 10 рублей. Каждый год дефецит полипропилена и на фоне дефицита рост цены.', 'Добрые, отзывчивые люди, готовые сразу обсуждать и решать возникающие вопросы.', 'техподдержка по ПП, Полилаб', 'Предоставление образцов новых продуктов', 'Желательно работать по скан доверенности.', 'Все хорошо.', 'компетентность, вежливость, оперативность', 'качественная работа нашего менеджера Алексея Ушакова', 'отличная работа нашего менеджера Алексея Ушакова, готовность помочь и поддержать, оперативность ответов на запросы, гибкая реакция на наши потребности в рамках его полномочий', 'положительно оценили реакцию и результат работы тех. специалиста оказавшего оперативную помощь в настройке тпа на новой марке пэвп.', 'Деловые встречи с командой Сибур', 'Вера в успех собственных планов', 'приятно работать с  Хусточкиной Натальей Геннадьевной и по отгрузкам на ТНХК с Баиновой Юлией Сергеевной', 'Профессионализм сотрудников и качество продукта.', 'Очень нравится простота работы и оперативность ведущего нас менеджера Олеси Черятовой.', 'Работа отдела продаж', '1) Менеджер вс ...
# English comments ['From the outside it appears a slow and rigid process. Greater flexibility needed', 'with fast shipment document flow could be faster as well.', 'docs slow', 'The delivery of L/C was a little late before, we hope your company can improve the delivery time', 'can be quicker', 'please issue contract a bit earlier.', 'No, I feel good', 'Loading documents should be send as soon as product is load', 'We had a few issues regarding the paperwork which were quickly resolved and have not reoccurred.', 'Logistics seems to work much better now than year ago!', 'to receive all copies together and originals together early', 'I must admit it is good and improving by the day as we get to know each other as partners', 'Markus is an excellent account manager and we appreciate his support', 'Stick to contracts', 'Weeky stable supply  and timely delivery', 'We have bought PP and other products too, and have been requesting for HDPE LBM Products for market seeding and penetration , we have had no luck so far. I am informed now that the same is coming thru so other traders.', 'shipment is not quickly.', 'Sfaffs including sales and supporting are hard working and considerable to customers.', 'When there is a problem to consult, reply very timely', 'You did a good job in the past', 'The availability and market knowledge of the sales manager', "Close contact via Vienna's office.", 'Great service. Stay on the same level.', 'Contact person are oke', 'Good communication!', 'much better payment conditions', 'Helpfulness in resolving problems.', 'The continuing desire to partner within the supply of MA but also to look at other opportunities to partner.', 'My contact person is very proactive and provides good service.', 'You have good people working for you.', 'mail reply response week', 'Communication', 'Look  forward to a fruitful mutal bsuiness developments of our business', 'Good cooperte', 'Quality of product and on-time dispatch of goods are good.', 'I very much appreciate the open and transparent communication. We have a solid and reliable relationship.', 'Service level is good. Challenges are in regards to pricing and availability.', 'Greater time and depth of business required to fully assess', 'documents flow (EAV form)', 'I hope the bill of lading number has the corresponding contract number .', 'docs slow, shipment ETA always change.', 'Aleady did a very good job.', 'Docs speed is not quickly', 'provide stable supply.', 'Booking the fastest vessel', '?????????OA??', 'Your service is good', 'I think the service is pretty good', 'we are satisfied with your current service', 'Sales manager should provide regular - weekly - updates on availability, possible shipment dates and prices', 'More regularity of supply + better knowledge/use of export incoterms + work on packaging (IBC price in line with competition)', 'More proactive technical service.', "As I mentioned before about the only negative moment we have : we'd like to return our old delay of payment. It was more comfortable for us.  Everything else is perfect.", 'To have stock in ARA zone always', 'to offer product availability in a proactive way, without be pushed by the customer', 'Improve quantities of material available in Europe in order to ensure higher volumes and improve the lead time', 'Sometimes there are too many employees of Sibur are involved in the process of our cooperation with Sibur and we are not aware who of them we should (supposed to) contact for specific reason/question.', 'We would like to get some credit line from you', 'Information on product availability', 'no prepayments anymore, more stable availability', 'deliveries on time', 'Reduce paperwork, speed up delivery and also prolong terms of payment at least 30 days.', 'There are not many comments. Maybe just try to inform or mutually agree on loading schedules in advance if possible.  Plus, try to organie a process of nominating and arranging the work of independent inspection companies, if it reuir ...
# Nul comments ['??????????,??????????', '???????', '??????,????????????????', '???????????????', '???????????????', '???????????????', '????,???', '????,???', '????,???', '????,???', '20220', '10500, 80520', '9200', '10500', '158', '???????????????']
#
#
# Amount of Russia comments:  690
# Amount of English comments:  189
# Amount of Nul comments:  16
#
#
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# Russian words ['технические', 'специалисты', 'пару', 'обращался', 'грамотно', 'емко', 'проконсультировали', 'технологическим', 'вопросам', 'спасибо']
# English words ['links', 'products', 'wedsite', 'broken', 'document', 'missing']
# Nul words ['?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?', '?']
#
#
# Sentiment Analysis of Eng
# > Positive: From the outside it appears a slow and rigid process. Greater flexibility needed
# > Positive: with fast shipment document flow could be faster as well.
# > Negative: docs slow
# > Positive: The delivery of L/C was a little late before, we hope your company can improve the delivery time
# > Negative: can be quicker
# > Positive: please issue contract a bit earlier.
# > Positive: No, I feel good
# > Negative: Loading documents should be send as soon as product is load
# > Positive: We had a few issues regarding the paperwork which were quickly resolved and have not reoccurred.
# > Positive: Logistics seems to work much better now than year ago!
# > Negative: to receive all copies together and originals together early
# > Positive: I must admit it is good and improving by the day as we get to know each other as partners
# > Positive: Markus is an excellent account manager and we appreciate his support
# > Negative: Stick to contracts
# > Positive: Weeky stable supply  and timely delivery
# > Positive: We have bought PP and other products too, and have been requesting for HDPE LBM Products for market seeding and penetration , we have had no luck so far. I am informed now that the same is coming thru so other traders.
# > Negative: shipment is not quickly.
# > Positive: Sfaffs including sales and supporting are hard working and considerable to customers.
# > Negative: When there is a problem to consult, reply very timely
# > Positive: You did a good job in the past
# > Negative: The availability and market knowledge of the sales manager
# > Negative: Close contact via Vienna's office.
# > Positive: Great service. Stay on the same level.
# > Negative: Contact person are oke
# > Positive: Good communication!
# > Positive: much better payment conditions
# > Positive: Helpfulness in resolving problems.
# > Positive: The continuing desire to partner within the supply of MA but also to look at other opportunities to partner.
# > Positive: My contact person is very proactive and provides good service.
# > Positive: You have good people working for you.
# > Negative: mail reply response week
# > Negative: Communication
# > Negative: Look  forward to a fruitful mutal bsuiness developments of our business
# > Positive: Good cooperte
# > Positive: Quality of product and on-time dispatch of goods are good.
# > Positive: I very much appreciate the open and transparent communication. We have a solid and reliable relationship.
# > Positive: Service level is good. Challenges are in regards to pricing and availability.
# > Positive: Greater time and depth of business required to fully assess
# > Negative: documents flow (EAV form)
# > Positive: I hope the bill of lading number has the corresponding contract number .
# > Negative: docs slow, shipment ETA always change.
# > Positive: Aleady did a very good job.
# > Negative: Docs speed is not quickly
# > Positive: provide stable supply.
# > Negative: Booking the fastest vessel
# > Negative: ?????????OA??
# > Positive: Your service is good
# > Positive: I think the service is pretty good
# > Positive: we are satisfied with your current service
# > Negative: Sales manager should provide regular - weekly - updates on availability, possible shipment dates and prices
# > Positive: More regularity of supply + better knowledge/use of export incoterms + work on packaging (IBC price in line with competition)
# > Positive: More proactive technical service.
# > Positive: As I mentioned before about the only negative moment we have : we'd like to return our old delay of payment. It was more comfortable for us.  Everything else is perfect.
# > Negative: To have stock in ARA zone always
# > Positive: to offer product availability in a proactive way, without be pushed by the customer
# > Positive: Improve quantities of material available in Europe in order to ensure higher volumes and improve the lead time
# > Negative: Sometimes there are too many employees of Sibur are involved in the process of our cooperation with Sibur and we are not aware who of them we should (supposed to) contact for specific reason/question.
# > Positive: We would like to get some credit line from you
# > Negative: Information on product availability
# > Positive: no prepayments anymore, more stable availability
# > Negative: deliveries on time
# > Negative: Reduce paperwork, speed up delivery and also prolong terms of payment at least 30 days.
# > Positive: There are not many comments. Maybe just try to inform or mutually agree on loading schedules in advance if possible.  Plus, try to organie a process of nominating and arranging the work of independent inspection companies, if it reuired by your Customers.
# > Negative: long-term cooperation-to become reliable partner
# > Positive: When your volume grows, a tank in the US would improve the flow of material as well as security of supply.
# > Negative: We need shorter lead time.
# > Negative: Logistics
# > Negative: To send us early documents to check and post early too.
# > Negative: Enhance the negotiation and availability of products.
# > Negative: fast quotation
# > Negative: Communication
# > Positive: increase dialogue to understand ME bsuiness needs.
# > Positive: all is perfect, keep that way
# > Negative: Some links of products are broken.  The TDS and SDS of the products on the Sibur International website are not up to date.
# > Negative: TDS and SDS of productions on website, some links is broken or not up to date.
# > Negative: TIMMING BETWEEN THE PAYMENT - DELIVERY
# > Positive: better payment terms
# > Positive: We would appreciate if Sibur had more consistent supply to Georgian market. We believe that our market has a lot of potential.
# > Negative: At the moment Sibur doesn't look interested to work with us
# > Negative: Need to reflect customer's purchase power when offering product price. Also, railcar idle stay penalty rate is high and turnover time is short.
# > Positive: Improve forecasts and commitments on available future volumes
# > Negative: delivery time
# > Positive: We would appreciate a quicker respond in urgent cases
# > Positive: Payment terms - insure customers Improve logistics - fast stable delivery without break Understand customer needs -e.g don't dispatch if we don't need more product, dispatch when we need product.
# > Negative: available quantities / price
# > Negative: Pricing is often not competitive. Longer payment terms are expected from a major supplier.
# > Positive: The sale manager action is very good. Unfortunately regularity of supply is not always there and there are some misuse of incoterms for some export destination.
# > Negative: Annual contract - we totally are. For the spot volumes - not always.
# > Negative: We only have bought the 2EHA.
# > Negative: no prepayments anymore...
# > Positive: Of course the price could always be better, but Sibur has done a good job at remaining competitive and supplying at, or above the promised quantities.
# > Positive: Regarding to Payment Term we suggest to allow us to proceed to Prepayment such as 30% Advance against Signed Contract and 70% against Copy of BL.
# > Negative: There  are not proposal since 12 months
# > Negative: Abandoning the term contract renewal discussions was very disappointing caused by surprising cuts in available volumes.
# > Negative: terms of payment - prepayment (question 15) so not flexible prices - not always represents daily market sentiment, situation of decreasing without any signals from the market (question 14)
# > Negative: I prefere to dealing not only throw AOM platform (trade secret)
# > Negative: sometime documents flow a bit delay (EAV form).
# > Negative: Shipment ETD is always changing.
# > Negative: very slow speed recently
# > Negative: supply not stable, sometime have, sometimes no.
# > Negative: shipment schedule sometimes delayed
# > Positive: good and rely you very soon when we have some problem.
# > Positive: We organize logistic by ourselves. Sibur is not related to it :)
# > Positive: Flexibility of logistics should be improved.
# > Negative: Not always the product is in ARA zone.
# > Negative: No availability
# > Positive: Perfect Logistics Service!
# > Positive: We would like to share our appreciation for speed of decision making and professionalism of Ms. Olga Kuznetsova and Ms. Maria Zakharova.
# > Positive: Overall, we are satisfied as a "4" is still very good. Part of this is the challenge being faced globally with the transportation of material but part was that the communication could have been a little better.
# > Positive: cmmuincatiosn could improve
# > Negative: TAKES TOO MUCH TIME IN EVERY STEP OF THE SALE....
# > Negative: last long waiting time from avizo date to actual delivery, delays compared to the contract period
# > Negative: need wider MFI: 1,0 and 3,0
# > Positive: pls consider to produce some MI:4 grades, thanks.
# > Negative: Product is oke, availabilty pour
# > Negative: No issues with product quality have been observed.
# > Negative: Quality is according to specification.
# > Positive: the major issue we have is the physical form of the product versus competitive products . i.e powder grades of Sibur are considered as crumbs by our rgeion
# > Positive: Quality with regards to oxygenates has improved significantly over the past few years. Iso-butane content on mix butane is outside common spec but we have reached commercial agreement.
# > Positive: Availability & pricing are both issues. Sometimes responses from SIBUR HQ are quite slow. There is a need to listen more carefully to local market feedback.
# > Positive: Greater decision making authority closer to the customer would be more effective where practical.
# > Positive: all good!
# > Negative: MFI 1 and 3  also needed.
# > Positive: Would be great to have more MT each month!
# > Positive: Very good.
# > Negative: We also Buy a Lot of PP from your  SIBUR but this survey does not allow me to specify many products that we buy and can buy.
# > Positive: good
# > Positive: good
# > Positive: good
# > Positive: pls consider produce some MI:4 grades, thanks.
# > Positive: good
# > Positive: good
# > Positive: good
# > Positive: good
# > Positive: The sales manager followed up very well and the service of the team was very good. No problem
# > Positive: The sales manager followed up very well and the service of the team was very good. No problem
# > Positive: The sales manager followed up very well and the service of the team was very good. No problem
# > Positive: The sales manager followed up very well and the service of the team was very good. No problem
# > Negative: quick action.  professional
# > Negative: quick action.  professional
# > Negative: quick action.  professional
# > Negative: request more continuously supply
# > Negative: quality to be upgraded for HD film and blow grades
# > Positive: good quality and good service.and it's better to short the presention days.
# > Negative: MFR 0.3 Continuous and steady supply
# > Positive: Your team work is very good, appreciate it.
# > Positive: Your team have done a good job, we are satisfied with their work
# > Positive: No, I feel good
# > Positive: No, I feel good
# > Negative: Be more reliable in volume availability
# > Positive: While you are very efficient for European sales - export ones are a bit more complicated due to misuse of incoterms.
# > Negative: We have factories in Gyor and Tatabanya. Sometime we order for the factory in Gyor and sometime for the factory in Tatabanya.
# > Negative: Methyl acrylate, Acrylic Acid
# > Negative: Too much paperwork!
# > Negative: We only buy few times the 2EHA because our consumption is not so regular as the BA.
# > Negative: prices not always competitive
# > Negative: Very professional and quick in reaction stuff
# > Negative: We have no availability and pour information about this
# > Negative: diethylene glycol
# > Positive: MEG, DEG - I like cooperating with Sibur team very much. They are very nice and professional.
# > Negative: Our main focus of work with Sibur has been pygas and C9 fractions. We are very plesed to work with the Sibur commercial team, especially Mr. Kirill Fillipov.
# > Negative: very proffesional
# > Positive: I find working with the Sibur team is a good experience. The team is very professional, quick to respond, and most important, that our business is important to Sibur.
# > Positive: Co-operation improved much. Bureaucracy of company much more time consuming than competitors. Maybe due to Russian legislation?
# > Negative: Due to our specific production plan, we prefer shorter lead time.
# > Negative: 3001 only
# > Positive: we would like to receive more fast the information about shipment and copies of documents. We need receive the documents to check earlier and the post of originals to show for our customs before the vessel arrives
# > Positive: Product is great, but it is not always available. We are working on pricing with your team.
# > Positive: Although the price did not match our target, we still ordered. However we would need better pricing policy in future for doing more business together
# > Negative: NBR 3345
# > Positive: The team is supportive but would like to see taking decisions  faster and more understanding of the special needs of our region
# > Positive: I would like to improve our comunication, because I am not satisfied with the speed of response.
# > Negative: HAVE TO WORK BETWEEN TIMES WE ORDER, YOU SEND THE INVOICE, YOU SEND THE MATERIAL....
# > Positive: Good support
# > Positive: Good support
# > Positive: From our company's perspective, we highly appreciate the professionalism of the team and their prompt feedback on the ongoing topics.
# > Positive: coperation with Sibur work team is fully satisfied
# > Positive: You can provide the product technical docs timely, and we are satisfied with your technical service
# > Negative: We have not contacted the Technical Team till now
# > Negative: Need more interaction between the two companies
# > Negative: he factory feedback that the product quality is all right
# > Positive: We are satisfied with your technical service currently
# > Positive: No, I feel good
# > Negative: We ask to propose formulations for foorcovering production.
# > Negative: Delivery dates on time not earlier-our schedules are sometimes so close for anyone changes
# > Negative: if possible to send all documents for check together
# > Negative: To have direct contcat withthe  techncial team and for Sibur to provide more technical studies about usage of their products .
# > Negative: The TDS and SDS of the products on the Sibur International website are not up to date.  Some links of products are broken.
# > Negative: Links of products on Wedsite, some of it is broken or document missing.

# %%
# English coments sentiemnt analysis
sia = SentimentIntensityAnalyzer()
sentiments = [(1, 0) if comment_is_positive(sia, comment) else (0, -1) for comment in englishcomments] 

# Create X and Y axis 
x_num = list(range(0, len(englishcomments)))
y_pos = list(map(lambda sentiment: sentiment[0], sentiments))
y_neg = list(map(lambda sentiment: sentiment[1], sentiments))

# Draw plot
plt.title('Unsorter Sentimental Analysis (Postive and Negative) of english comments')
plt.ylabel('Postive and Negative')
plt.xlabel('Number of english comments')
plt.plot(x_num, y_pos, "-g")
plt.plot(x_num, y_neg, "-r")
plt.legend(['Positive', 'Negative'])
plt.show()

y_sorted_pos = sorted(y_pos)
y_sorted_neg = sorted(y_neg)

# Draw plots
plt.title('Sorted Sentimental Analysis (Postive and Negative) of english comments')
plt.ylabel('Postive and Negative')
plt.xlabel('Number of english comments')
plt.plot(x_num, y_sorted_pos, "-g")
plt.plot(x_num, y_sorted_neg, "-r")
plt.legend(['Positive', 'Negative'])

print(f"The quantity of Positive comments: {y_sorted_pos.count(1)}")
print(f"The quantity of Negative comments: {y_sorted_neg.count(-1)}")
print(f"The overall or total of comments: {len(x_num)}")

plt.show()

# Pie chart, where the slices will be ordered and plotted counter-clockwise:

# Calculation of ratio
# Positive ratio
#189 = 100%
#98 = percent

# Negative ratio
#189 = 100%
#91 = percent

pos_percent = round(y_pos.count(1) * 100 / len(x_num))
neg_percent = round(y_neg.count(-1) * 100 / len(x_num))

print(f"Positive comments percents {round(y_pos.count(1) * 100 / len(x_num))}%")
print(f"Negative comments percents {round(y_neg.count(-1) * 100 / len(x_num))}%")

labels = 'Positive', 'Negative'
sizes = [pos_percent, neg_percent]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

print(f"The quantity of Positive comments: {y_pos.count(1)}")
print(f"The quantity of Negative comments: {y_neg.count(-1)}")
print(f"The overall or total of comments: {len(x_num)}")

plt.show()

# Draw chart bar
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
sentiments = ['Positive', 'Negative']
comments = [y_pos.count(1), y_neg.count(-1)]
ax.bar(sentiments, comments, color = ['g', 'r'])
plt.show()
# Out:
# The quantity of Positive comments: 98
# The quantity of Negative comments: 91
# The overall or total of comments: 189
# Positive comments percents 52%
# Negative comments percents 48%
# The quantity of Positive comments: 98
# The quantity of Negative comments: 91
# The overall or total of comments: 189

# %%
# Visualization of Russian comments

sentiments = GetSentimentsFrom(russiancomments)

x_num = list(range(0, len(russiancomments)))
y_pos = GetSentiementByKey(sentiments, 'positive')
y_neg = GetSentiementByKey(sentiments, 'negative')
y_neu = GetSentiementByKey(sentiments, 'neutral')

# Quantity or count of comments 
def Count(comments, greater: float = 0.6):
    return sum(percent > greater for percent in comments)
    
quantity_pos = Count(y_pos)
quantity_neg = Count(y_neg)
quantity_neu = Count(y_neu)

# Draw plot   
plt.title('Unsorter Sentimental Analysis (Postive and Negative) of comments')
plt.ylabel('Percent of Postive and Negative')
plt.xlabel('Number of Russian comments')
plt.plot(x_num_comments, y_pos_comments, "-g")
plt.plot(x_num_comments, y_neg_comments, "-r")
plt.legend(['Positive', 'Negative'])
plt.show()

print(f"The quantity of comments")
print(f"The quantity of Positive: {Count(y_sorted_pos, 0.1)}")
print(f"The quantity of Negative: {Count(y_sorted_neg, 0.1)}")
print(f"The rest of comments: {len(x_num) - Count(y_sorted_pos, 0.1) - Count(y_sorted_neg, 0.1)}")
print(f"The overall or total of coements: {len(x_num)}")
print("\n\r")

y_sorted_pos = sorted(y_pos_comments)
y_sorted_neg = sorted(y_neg_comments)

# Draw plots
plt.title('Sorted Sentimental Analysis (Postive and Negative) of russian comments')
plt.ylabel('Percent of Postive and Negative')
plt.xlabel('Number of russian comments')
plt.plot(x_num, y_sorted_pos, "-g")
plt.plot(x_num, y_sorted_neg, "-r")
plt.legend(['Positive', 'Negative'])
plt.show()

print(f"The quantity of comments")
print(f"The quantity of Positive: {Count(y_sorted_pos, 0.1)}")
print(f"The quantity of Negative: {Count(y_sorted_neg, 0.1)}")
print(f"The rest of comments: {len(x_num) - Count(y_sorted_pos, 0.1) - Count(y_sorted_neg, 0.1)}")
print(f"The overall or total of coements: {len(x_num)}")
print("\n\r")

# Display overall info 

# Calculation of ratio
# Positive ratio
#overall = 100%
#pos_of_comments = percent

# Negative ratio
#overall = 100%
#neg_of_comments = percent

# Rest ratio
#overall = 100%
#rest_of_comments = percent

pos_percent = (quantity_pos * 100 / len(x_num))
neg_percent = (quantity_neg * 100 / len(x_num))
neu_percent = (quantity_neu * 100 / len(x_num))
overall = len(x_num)

rest_percent = ((overall - quantity_pos - quantity_neg - quantity_neu) * 100 / overall)

labels = 'Positive', 'Negative', 'Neutral', 'Rest of comments'
sizes = [pos_percent, neg_percent, neu_percent, rest_percent]
explode = (0.1, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

print(f"The quantity of comments")
print(f"The quantity of Positive: {quantity_pos}")
print(f"The quantity of Negative: {quantity_neg}")
print(f"The quantity of Neutral: {quantity_neu}")
print(f"The rest of comments: {(overall - quantity_pos - quantity_neg - quantity_neu)}")
print(f"The Total of comments: {len(x_num)}")
print("\n\r")

print(f"Ratio of comments in percents")
print(f"Positive comments percents: {round(pos_percent)}%")
print(f"Negative comments percents: {round(neg_percent)}%")
print(f"Neutral comments percents: {round(neu_percent)}%")
print(f"Rest of comments percents: {round(rest_percent)}%")

# Draw chart bar
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
sentiments = ['Positive', 'Negative', 'Neutral']
comments = [Count(y_pos), Count(y_neg), Count(y_neu)]
ax.bar(sentiments, comments, color = ['g', 'r', 'b'])
plt.show()
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# The quantity of comments
# The quantity of Positive: 144
# The quantity of Negative: 301
# The rest of comments: 245
# The overall or total of coements: 690
# The quantity of comments
# The quantity of Positive: 144
# The quantity of Negative: 301
# The rest of comments: 245
# The overall or total of coements: 690
# The quantity of comments
# The quantity of Positive: 32
# The quantity of Negative: 7
# The quantity of Neutral: 497
# The rest of comments: 154
# The Total of comments: 690
#
#
# Ratio of comments in percents
# Positive comments percents: 5%
# Negative comments percents: 1%
# Neutral comments percents: 72%
# Rest of comments percents: 22%

# %%
# Visualization of English comments
# you can use dictionary there pisitve X + 1 (1nd col) and negative X + 2 (2nd col) is key or X axis  

# English coments sentiemnt analysis
sia = SentimentIntensityAnalyzer()
sentiments = [comment_is_positive_percents(sia, comment) for comment in englishcomments] 

# Create X and Y axis 
x_num = list(range(0, len(englishcomments)))
y_pos = GetSentiementByKey(sentiments, 0)
y_neg = GetSentiementByKey(sentiments, 1)

# Draw plot
plt.title('Unsorter Sentimental Analysis (Postive and Negative) of english comments')
plt.ylabel('Percent of Postive and Negative')
plt.xlabel('Number of english comments')
plt.plot(x_num_comments, y_pos_comments, "-g")
plt.plot(x_num_comments, y_neg_comments, "-r")
plt.legend(['Positive', 'Negative'])
plt.show()

y_sorted_pos = sorted(y_pos)
y_sorted_neg = sorted(y_neg)

# Draw plots
plt.title('Sorted Sentimental Analysis (Postive and Negative) of english comments')
plt.ylabel('Percent of Postive and Negative')
plt.xlabel('Number of english comments')
plt.plot(x_num, y_sorted_pos, "-g")
plt.plot(x_num, y_sorted_neg, "-r")
plt.legend(['Positive', 'Negative'])
plt.show()

# %%
#Extract all parts of speech from any text
chunker = RegexpParser("""
    NP: {<DT>?<JJ>*<NN>} #To extract Noun Phrases
    P: {<IN>}            #To extract Prepositions
    V: {<V.*>}           #To extract Verbs
    PP: {<p> <NP>}       #To extract Prepositional Phrases
    VP: {<V> <NP|PP>*}   #To extract Verb Phrases
    """)

# Find all parts of speech in above sentence
tagged = pos_tag(word_tokenize(englishcomments[0]))

chunked = chunker.parse(tagged)
nltk.draw.tree.TreeView(chunked)._cframe.print_to_file('/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/output.ps')

#args = ["convert", "/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/output.ps", "/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/output.png"]

def convert_to_png(path):
    img = Image.open(path)
    img.save("output.png")

path='/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/output.ps'
convert_to_png(path)

Image.open('/Users/lucifer/Desktop/20220504_DataScience_Python_NLTK_PROFI.ru_Nelya/output.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=903x201 at 0x7FEC932DF3A0>

# %%
# Find all parts of speech in above sentence
tagged = pos_tag(word_tokenize(russiancomments[0]))

#Extract all parts of speech from any text
chunker = RegexpParser("""
                    NP: {<DT>?<JJ>*<NN>} #To extract Noun Phrases
                    P: {<IN>}            #To extract Prepositions
                    V: {<V.*>}           #To extract Verbs
                    PP: {<p> <NP>}       #To extract Prepositional Phrases
                    VP: {<V> <NP|PP>*}   #To extract Verb Phrases
                    """)

# Print all parts of speech in above sentence
output = chunker.parse(tagged)
# To draw the parse tree
output.draw()
